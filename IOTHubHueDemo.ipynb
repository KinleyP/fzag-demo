# %%
# !pip install azure-iothub-device-client
# !pip install azure-iothub-service-client

# %%
# Copyright (c) Microsoft. All rights reserved.
# Licensed under the MIT license. See LICENSE file in the project root for full license information.

import random
import time
import sys

# Using the Python Device SDK for IoT Hub:
#   https://github.com/Azure/azure-iot-sdk-python
# The sample connects to a device-specific MQTT endpoint on your IoT Hub.
import iothub_client
# pylint: disable=E0611
from iothub_client import IoTHubClient, IoTHubClientError, IoTHubTransportProvider, IoTHubClientResult
from iothub_client import IoTHubMessage, IoTHubMessageDispositionResult, IoTHubError, DeviceMethodReturnValue

# The device connection string to authenticate the device with your IoT hub.
# Using the Azure CLI:
# az iot hub device-identity show-connection-string --hub-name {YourIoTHubName} --device-id MyNodeDevice --output table
CONNECTION_STRING = "HostName=IOTHubEdzard2.azure-devices.net;DeviceId=HUELampColor1;SharedAccessKey=ZsRkTyfZHBsfPjin8OlNQa7VLIufo9hzjpiA26wIdLs="

# Using the MQTT protocol.
PROTOCOL = IoTHubTransportProvider.MQTT
MESSAGE_TIMEOUT = 10000

# Define the JSON message to send to IoT Hub.
TEMPERATURE = 20.0
HUMIDITY = 60
MSG_TXT = "{\"temperature\": %.2f,\"humidity\": %.2f}"

def send_confirmation_callback(message, result, user_context):
    print ( "IoT Hub responded to message with status: %s" % (result) )

def iothub_client_init():
    # Create an IoT Hub client
    client = IoTHubClient(CONNECTION_STRING, PROTOCOL)
    return client

def iothub_client_telemetry_sample_run():

    try:
        client = iothub_client_init()
        print ( "IoT Hub device sending periodic messages, press Ctrl-C to exit" )

        while True:
            
# Build the message with simulated telemetry values.
            temperature = TEMPERATURE + (random.random() * 15)
            humidity = HUMIDITY + (random.random() * 20)
            msg_txt_formatted = MSG_TXT % (temperature, humidity)
            message = IoTHubMessage(msg_txt_formatted)
            # Add a custom application property to the message.
            # An IoT hub can filter on these properties without access to the message body.
            prop_map = message.properties()
            if temperature > 30:
              prop_map.add("temperatureAlert", "true")
            else:
              prop_map.add("temperatureAlert", "false")

            # Send the message.
            print( "Sending message: %s" % message.get_string() )
            client.send_event_async(message, send_confirmation_callback, None)
            time.sleep(5)

    except IoTHubError as iothub_error:
        print ( "Unexpected error %s from IoTHub" % iothub_error )
        return
    except KeyboardInterrupt:
        print ( "IoTHubClient sample stopped" )

if __name__ == '__main__':
    print ( "IoT Hub Quickstart #1 - Simulated device" )
    print ( "Press Ctrl-C to exit" )
    iothub_client_telemetry_sample_run()
# Out:
# IoT Hub Quickstart #1 - Simulated device
# Press Ctrl-C to exit
# IoT Hub device sending periodic messages, press Ctrl-C to exit
# Sending message: {"temperature": 23.21,"humidity": 68.79}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.30,"humidity": 75.87}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.04,"humidity": 66.72}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.14,"humidity": 66.03}
# Sending message: {"temperature": 23.03,"humidity": 67.86}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.71,"humidity": 77.64}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.80,"humidity": 71.63}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.88,"humidity": 78.09}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.79,"humidity": 63.21}
# Sending message: {"temperature": 28.62,"humidity": 71.25}
# Sending message: {"temperature": 29.33,"humidity": 62.92}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.73,"humidity": 67.08}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.68,"humidity": 79.12}
# Sending message: {"temperature": 21.88,"humidity": 74.51}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.56,"humidity": 70.13}
# Sending message: {"temperature": 29.79,"humidity": 74.10}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.84,"humidity": 79.60}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.24,"humidity": 66.88}
# Sending message: {"temperature": 29.03,"humidity": 66.70}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.28,"humidity": 74.45}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.16,"humidity": 67.93}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.04,"humidity": 71.70}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.86,"humidity": 63.51}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.89,"humidity": 70.67}
# Sending message: {"temperature": 23.84,"humidity": 64.46}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.87,"humidity": 63.37}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.77,"humidity": 60.64}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.85,"humidity": 68.07}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.39,"humidity": 65.74}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.41,"humidity": 79.40}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.52,"humidity": 74.96}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.83,"humidity": 63.28}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.00,"humidity": 79.38}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.64,"humidity": 64.72}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.13,"humidity": 68.09}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.45,"humidity": 69.07}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.52,"humidity": 63.11}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.57,"humidity": 64.90}
# Sending message: {"temperature": 28.75,"humidity": 70.40}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.53,"humidity": 74.53}
# Sending message: {"temperature": 32.32,"humidity": 76.71}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.59,"humidity": 69.55}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.49,"humidity": 77.26}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.61,"humidity": 64.50}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.23,"humidity": 70.25}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: MESSAGE_TIMEOUT
# Sending message: {"temperature": 31.83,"humidity": 70.64}
# Sending message: {"temperature": 30.28,"humidity": 79.48}
# Sending message: {"temperature": 26.33,"humidity": 64.94}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.65,"humidity": 63.49}
# Sending message: {"temperature": 26.04,"humidity": 76.89}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.42,"humidity": 65.94}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.45,"humidity": 67.89}
# Sending message: {"temperature": 25.49,"humidity": 63.60}
# Sending message: {"temperature": 33.87,"humidity": 77.69}
# Sending message: {"temperature": 21.76,"humidity": 79.41}
# Sending message: {"temperature": 32.13,"humidity": 61.33}
# Sending message: {"temperature": 26.14,"humidity": 73.53}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.63,"humidity": 71.37}
# Sending message: {"temperature": 24.34,"humidity": 71.49}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.33,"humidity": 73.00}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.27,"humidity": 65.95}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.70,"humidity": 61.38}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.95,"humidity": 72.25}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.12,"humidity": 79.82}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.94,"humidity": 75.24}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.48,"humidity": 64.90}
# Sending message: {"temperature": 29.16,"humidity": 74.28}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.93,"humidity": 67.46}
# Sending message: {"temperature": 22.87,"humidity": 64.73}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.26,"humidity": 70.55}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: MESSAGE_TIMEOUT
# Sending message: {"temperature": 21.73,"humidity": 73.61}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.72,"humidity": 68.29}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.51,"humidity": 75.13}
# Sending message: {"temperature": 21.38,"humidity": 64.33}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.38,"humidity": 69.13}
# Sending message: {"temperature": 22.35,"humidity": 62.73}
# Sending message: {"temperature": 28.73,"humidity": 63.40}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.20,"humidity": 70.27}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.00,"humidity": 69.10}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.28,"humidity": 61.31}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.81,"humidity": 72.45}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.34,"humidity": 73.58}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.01,"humidity": 75.89}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.36,"humidity": 78.55}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.41,"humidity": 61.63}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.32,"humidity": 61.79}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.14,"humidity": 65.52}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.60,"humidity": 73.25}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.90,"humidity": 71.12}
# Sending message: {"temperature": 28.70,"humidity": 65.89}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.06,"humidity": 62.77}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.33,"humidity": 67.23}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.84,"humidity": 66.13}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.18,"humidity": 62.05}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.26,"humidity": 67.68}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.35,"humidity": 60.72}
# Sending message: {"temperature": 28.98,"humidity": 66.92}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: MESSAGE_TIMEOUT
# Sending message: {"temperature": 22.43,"humidity": 67.05}
# Sending message: {"temperature": 20.28,"humidity": 75.35}
# Sending message: {"temperature": 27.87,"humidity": 73.80}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.58,"humidity": 77.72}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.48,"humidity": 75.73}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.52,"humidity": 72.98}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.35,"humidity": 76.13}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.59,"humidity": 63.27}
# Sending message: {"temperature": 33.63,"humidity": 65.24}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.37,"humidity": 61.30}
# Sending message: {"temperature": 32.82,"humidity": 77.47}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.86,"humidity": 64.77}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.46,"humidity": 71.10}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.99,"humidity": 65.72}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.39,"humidity": 70.51}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.35,"humidity": 71.24}
# Sending message: {"temperature": 20.03,"humidity": 72.93}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.49,"humidity": 72.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.92,"humidity": 67.92}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.55,"humidity": 73.80}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.24,"humidity": 62.14}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.35,"humidity": 78.71}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.26,"humidity": 72.98}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.21,"humidity": 67.00}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.76,"humidity": 73.82}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.47,"humidity": 69.51}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.72,"humidity": 68.10}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.35,"humidity": 73.71}
# Sending message: {"temperature": 23.03,"humidity": 60.34}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.93,"humidity": 63.47}
# Sending message: {"temperature": 21.82,"humidity": 68.07}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.51,"humidity": 71.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.59,"humidity": 61.31}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.73,"humidity": 72.68}
# IoT Hub responded to message with status: MESSAGE_TIMEOUT
# Sending message: {"temperature": 26.35,"humidity": 62.81}
# Sending message: {"temperature": 25.86,"humidity": 67.55}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.14,"humidity": 63.44}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.62,"humidity": 71.74}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.79,"humidity": 69.04}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.40,"humidity": 76.44}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.59,"humidity": 66.16}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.24,"humidity": 64.66}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.21,"humidity": 76.17}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.31,"humidity": 64.25}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.94,"humidity": 78.36}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.04,"humidity": 72.00}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.53,"humidity": 76.85}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.48,"humidity": 61.85}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.03,"humidity": 68.70}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.19,"humidity": 67.92}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.16,"humidity": 79.58}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.08,"humidity": 72.02}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.55,"humidity": 77.54}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.27,"humidity": 60.30}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.27,"humidity": 67.81}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.17,"humidity": 66.14}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.95,"humidity": 72.07}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.05,"humidity": 79.26}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.37,"humidity": 61.42}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.45,"humidity": 77.21}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.59,"humidity": 63.14}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.49,"humidity": 61.28}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.19,"humidity": 71.89}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.20,"humidity": 69.66}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.32,"humidity": 79.72}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.96,"humidity": 63.15}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.19,"humidity": 64.20}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.94,"humidity": 66.94}
# Sending message: {"temperature": 31.08,"humidity": 79.36}
# Sending message: {"temperature": 25.21,"humidity": 77.13}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.34,"humidity": 73.08}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.63,"humidity": 70.05}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.92,"humidity": 75.77}
# Sending message: {"temperature": 33.80,"humidity": 69.92}
# Sending message: {"temperature": 32.65,"humidity": 75.69}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.75,"humidity": 61.09}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.60,"humidity": 68.99}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.76,"humidity": 79.25}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.42,"humidity": 74.60}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.36,"humidity": 61.98}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.74,"humidity": 66.55}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.23,"humidity": 74.87}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.67,"humidity": 79.07}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.98,"humidity": 73.35}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.26,"humidity": 66.00}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.50,"humidity": 66.49}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.33,"humidity": 62.57}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.76,"humidity": 64.51}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.83,"humidity": 72.28}
# Sending message: {"temperature": 20.80,"humidity": 70.25}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.42,"humidity": 61.00}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.21,"humidity": 67.08}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.12,"humidity": 62.63}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.28,"humidity": 66.89}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.05,"humidity": 62.58}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.84,"humidity": 60.18}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.46,"humidity": 79.82}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.96,"humidity": 63.42}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.48,"humidity": 72.52}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.03,"humidity": 74.10}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.36,"humidity": 62.44}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.70,"humidity": 67.26}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.84,"humidity": 67.51}
# Sending message: {"temperature": 33.07,"humidity": 63.41}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.24,"humidity": 74.88}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.70,"humidity": 62.26}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.22,"humidity": 63.57}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.69,"humidity": 65.83}
# Sending message: {"temperature": 33.36,"humidity": 74.31}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.70,"humidity": 71.00}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.83,"humidity": 70.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.77,"humidity": 71.13}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.31,"humidity": 60.86}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: MESSAGE_TIMEOUT
# Sending message: {"temperature": 29.58,"humidity": 65.93}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.69,"humidity": 74.43}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.73,"humidity": 68.94}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.73,"humidity": 73.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.85,"humidity": 64.59}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.57,"humidity": 63.39}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.55,"humidity": 69.28}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.49,"humidity": 61.53}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.98,"humidity": 78.92}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.43,"humidity": 62.82}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.26,"humidity": 72.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.18,"humidity": 60.05}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.40,"humidity": 70.79}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.49,"humidity": 79.57}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.08,"humidity": 73.43}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.89,"humidity": 68.40}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.97,"humidity": 62.96}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.08,"humidity": 72.92}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.50,"humidity": 76.15}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.24,"humidity": 70.02}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.78,"humidity": 61.67}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.21,"humidity": 74.17}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.21,"humidity": 79.21}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.98,"humidity": 74.32}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.32,"humidity": 60.10}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.08,"humidity": 72.67}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.00,"humidity": 72.66}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.13,"humidity": 64.32}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.47,"humidity": 77.29}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.64,"humidity": 77.92}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.99,"humidity": 70.01}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.80,"humidity": 68.55}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.02,"humidity": 75.65}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.44,"humidity": 67.32}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.89,"humidity": 60.87}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.49,"humidity": 66.33}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.70,"humidity": 79.15}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.29,"humidity": 61.32}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.96,"humidity": 76.06}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.64,"humidity": 72.55}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.82,"humidity": 73.85}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.66,"humidity": 63.65}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.18,"humidity": 73.34}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.68,"humidity": 77.47}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.45,"humidity": 68.11}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.97,"humidity": 76.69}
# Sending message: {"temperature": 32.27,"humidity": 74.17}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.29,"humidity": 65.28}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.75,"humidity": 66.40}
# Sending message: {"temperature": 20.03,"humidity": 69.29}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.24,"humidity": 70.46}
# Sending message: {"temperature": 23.70,"humidity": 66.53}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.65,"humidity": 68.56}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.06,"humidity": 70.48}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.33,"humidity": 66.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.58,"humidity": 67.89}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.16,"humidity": 69.04}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.27,"humidity": 67.96}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.48,"humidity": 67.46}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.28,"humidity": 79.08}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.30,"humidity": 73.20}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.53,"humidity": 66.10}
# Sending message: {"temperature": 23.01,"humidity": 72.15}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.25,"humidity": 74.86}
# Sending message: {"temperature": 30.92,"humidity": 62.80}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.14,"humidity": 79.05}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.06,"humidity": 77.67}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.24,"humidity": 69.00}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.55,"humidity": 79.16}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.15,"humidity": 78.30}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.05,"humidity": 62.50}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.24,"humidity": 60.28}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.26,"humidity": 72.11}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.34,"humidity": 77.86}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.20,"humidity": 65.55}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.79,"humidity": 65.87}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.90,"humidity": 77.02}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.54,"humidity": 76.36}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.41,"humidity": 70.77}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.01,"humidity": 77.83}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.61,"humidity": 69.96}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.70,"humidity": 68.50}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.84,"humidity": 61.05}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.02,"humidity": 70.08}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.08,"humidity": 78.37}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.05,"humidity": 70.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.84,"humidity": 68.42}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.67,"humidity": 61.97}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.74,"humidity": 67.82}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.23,"humidity": 67.39}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.47,"humidity": 60.87}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.23,"humidity": 76.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.59,"humidity": 77.50}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.49,"humidity": 62.53}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.38,"humidity": 65.94}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.84,"humidity": 68.29}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.37,"humidity": 76.19}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.92,"humidity": 69.30}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.74,"humidity": 69.33}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.66,"humidity": 60.26}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.61,"humidity": 61.08}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.36,"humidity": 78.24}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.74,"humidity": 72.66}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 27.18,"humidity": 76.45}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.90,"humidity": 77.14}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.37,"humidity": 76.03}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.97,"humidity": 66.72}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.81,"humidity": 75.56}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.04,"humidity": 60.23}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.03,"humidity": 75.20}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.48,"humidity": 63.76}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.22,"humidity": 74.51}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.52,"humidity": 68.19}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.71,"humidity": 71.84}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.31,"humidity": 73.86}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.99,"humidity": 75.82}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.94,"humidity": 71.43}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 32.10,"humidity": 79.21}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.11,"humidity": 61.36}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.24,"humidity": 74.85}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 33.03,"humidity": 70.79}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 24.00,"humidity": 77.73}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.57,"humidity": 67.37}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 29.43,"humidity": 75.30}
# Sending message: {"temperature": 28.70,"humidity": 61.70}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.77,"humidity": 78.26}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.45,"humidity": 67.11}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.40,"humidity": 75.45}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.87,"humidity": 62.10}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.15,"humidity": 60.08}
# Sending message: {"temperature": 25.59,"humidity": 73.39}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.96,"humidity": 74.87}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.52,"humidity": 72.22}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 34.81,"humidity": 72.24}
# Sending message: {"temperature": 21.71,"humidity": 74.40}
# Sending message: {"temperature": 32.84,"humidity": 62.82}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.94,"humidity": 62.96}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.97,"humidity": 74.32}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.74,"humidity": 76.09}
# Sending message: {"temperature": 22.70,"humidity": 73.28}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.82,"humidity": 68.53}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 26.01,"humidity": 78.21}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.01,"humidity": 72.04}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.93,"humidity": 66.10}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 22.99,"humidity": 69.03}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 21.95,"humidity": 72.79}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 23.46,"humidity": 66.55}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 30.88,"humidity": 66.93}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: MESSAGE_TIMEOUT
# Sending message: {"temperature": 26.06,"humidity": 75.88}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 25.21,"humidity": 60.34}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 28.42,"humidity": 79.71}
# IoT Hub responded to message with status: OK
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 31.09,"humidity": 64.41}
# IoT Hub responded to message with status: OK
# Sending message: {"temperature": 20.81,"humidity": 75.24}
# Sending message: {"temperature": 29.82,"humidity": 65.17}
# IoT Hub responded to message with status: OK
